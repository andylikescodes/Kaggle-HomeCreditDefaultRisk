# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tools as tls
# %matplotlib inline

# %%
df, _ = tls.read_in_data()

# %%
unique_types = np.unique(df.dtypes)

# %%
unique_types, dictionary = tls.get_cols_for_dtype(df)

# %%
float_cols = dictionary[unique_types[1]]

# %%
float_cols.append('TARGET')

# %%
df_floats = df.loc[:, cat_cols]

# %%
df_floats.shape
# Out:
# (307511, 66)

# %%
df_cats.head()
# Out:
#             AMT_INCOME_TOTAL  AMT_CREDIT  AMT_ANNUITY  AMT_GOODS_PRICE  \
# SK_ID_CURR
# 100002              202500.0    406597.5      24700.5         351000.0
# 100003              270000.0   1293502.5      35698.5        1129500.0
# 100004               67500.0    135000.0       6750.0         135000.0
# 100006              135000.0    312682.5      29686.5         297000.0
# 100007              121500.0    513000.0      21865.5         513000.0
#
#             REGION_POPULATION_RELATIVE  DAYS_REGISTRATION  OWN_CAR_AGE  \
# SK_ID_CURR
# 100002                        0.018801            -3648.0          NaN
# 100003                        0.003541            -1186.0          NaN
# 100004                        0.010032            -4260.0         26.0
# 100006                        0.008019            -9833.0          NaN
# 100007                        0.028663            -4311.0          NaN
#
#             CNT_FAM_MEMBERS  EXT_SOURCE_1  EXT_SOURCE_2   ...    \
# ...
